# %%
import pandas as pd
df = pd.read_csv("data/credit_features.csv")
print(sorted(df.columns.tolist()))
# Out:
# ['CREDIT_Z_COMPOSITE', 'DGS10', 'DGS2', 'Date', 'HY_OAS', 'HY_OAS_chg_21d', 'HY_OAS_z_252', 'IG_OAS', 'IG_OAS_chg_21d', 'IG_OAS_z_252', 'SLOPE_2s10s_bps', 'SLOPE_2s10s_bps_chg_21d', 'SLOPE_2s10s_bps_z_252', 'VIXCLS', 'VIXCLS_chg_21d', 'VIXCLS_z_252']
